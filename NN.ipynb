# %% [markdown]
# make simple nn with help of pytorch

# %%
import torch
import torch.nn as nn


class NeuralNetwork(nn.Module):
    def __init__(self):
        super().__init__()
        self.fc1 = nn.Linear(10, 16)
        self.fc2 = nn.Linear(16, 8)
        self.fc3 = nn.Linear(8, 1)

    def forward(self, x):
        x = torch.relu(self.fc1(x))
        x = torch.relu(self.fc2(x))
        x = torch.sigmoid(self.fc3(x))
        return x


model = NeuralNetwork()
print(model)
# Out:
# NeuralNetwork(
#   (fc1): Linear(in_features=10, out_features=16, bias=True)
#   (fc2): Linear(in_features=16, out_features=8, bias=True)
#   (fc3): Linear(in_features=8, out_features=1, bias=True)
# )

# %% [markdown]
# model loss function and optimizer

# %%
model = NeuralNetwork()
criterion = nn.BCELoss()
optimizer = torch.optim.Adam(model.parameters(), lr=0.01)

# %%
inputs = torch.randn((100, 10))
targets = torch.randint(0, 2, (100, 1)).float()
epochs = 100

for epoch in range(epochs):
    optimizer.zero_grad()
    outputs = model(inputs)
    loss = criterion(outputs, targets)
    loss.backward()
    optimizer.step()

    if (epoch + 1) % 5 == 0:
        print(f"Epoch [{epoch+1}/{epochs}], Loss: {loss.item():.4f}")
# Out:
# Epoch [5/100], Loss: 0.9392
# Epoch [10/100], Loss: 0.5925
# Epoch [15/100], Loss: 0.5150
# Epoch [20/100], Loss: 0.4795
# Epoch [25/100], Loss: 0.4385
# Epoch [30/100], Loss: 0.4055
# Epoch [35/100], Loss: 0.3752
# Epoch [40/100], Loss: 0.3486
# Epoch [45/100], Loss: 0.3197
# Epoch [50/100], Loss: 0.2864
# Epoch [55/100], Loss: 0.2536
# Epoch [60/100], Loss: 0.2210
# Epoch [65/100], Loss: 0.1894
# Epoch [70/100], Loss: 0.1615
# Epoch [75/100], Loss: 0.1377
# Epoch [80/100], Loss: 0.1170
# Epoch [85/100], Loss: 0.0980
# Epoch [90/100], Loss: 0.0805
# Epoch [95/100], Loss: 0.0663
# Epoch [100/100], Loss: 0.0543

# %%
model.eval()
with torch.no_grad():
    test_data = torch.randn((4, 10)) # Generate 4 samples, each with 10 random features
    predictions = model(test_data)
    print(f'Predictions:\n{predictions}')
# Out:
# Predictions:
# tensor([[1.5089e-04],
#         [4.9668e-02],
#         [5.2119e-04],
#         [9.8684e-01]])
